# %%
# Run the data ingest notebook
dbutils.notebook.run("1_data_ingestion_clean", 600)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create the training data set.
dbutils.notebook.run("2_feature_engineering_clean", 590, 
                     {"FEATURES_TABLE": "training_data", 
                      "START_DATE": "2000-01-01",  
                      "zEND_DATE": "2015-10-30"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create the test data set.
dbutils.notebook.run("2_feature_engineering_clean", 590, 
                     {"FEATURES_TABLE": "testing_data", 
                      "START_DATE": "2015-11-15",  
                      "zEND_DATE": "2018-10-30"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Create the random_forest model.
dbutils.notebook.run("3_model_building", 570, 
                     {"TESTING_TABLE": "testing_data", 
                      "TRAINING_TABLE": "training_data",
                     "model": "RandomForest"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
